# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train, x_test = x_train / 255., x_test / 255.

# %%
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10))

# %%
loss = SparseCategoricalCrossentropy(from_logits=True)
model.compile(optimizer='adam', loss=loss, metrics=['acc'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.2940 - acc: 0.9153
# Epoch 2/5
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.1435 - acc: 0.9575
# Epoch 3/5
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.1074 - acc: 0.9679
# Epoch 4/5
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0878 - acc: 0.9729
# Epoch 5/5
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.0749 - acc: 0.9764

# %%
model.evaluate(x_test, y_test, verbose=2)
# Out:
# 10000/10000 - 0s - loss: 0.0709 - acc: 0.9777
# [0.07086889516133815, 0.9777]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.imshow(x_test[0])

# %%
test = x_test[0].copy()
test = test.reshape((1, 28, 28))
np.argmax(model.predict(test))
# Out:
# 7
